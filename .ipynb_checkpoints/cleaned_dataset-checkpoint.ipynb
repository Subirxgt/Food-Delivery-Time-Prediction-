# %%
import pandas as pd
import json

# %%
with open("India-Food-Delivery-Time-Prediction.txt", "r") as file:
    raw_text = file.read()

# Parse the text as JSON
data = json.loads(raw_text)

# Convert to DataFrame
df = pd.DataFrame(data)

# %%
df.to_csv("food_delivery_data.csv", index=False)
df
# Out:
#             ID Delivery_person_ID Delivery_person_Age Delivery_person_Ratings  \
# 0      0x4607     INDORES13DEL02                   37                     4.9
# 1      0xb379     BANGRES18DEL02                   34                     4.5
# 2      0x5d6d     BANGRES19DEL01                   23                     4.4
# 3      0x7a6a    COIMBRES13DEL02                   38                     4.7
# 4      0x70a2     CHENRES12DEL01                   32                     4.6
# ...        ...                ...                 ...                     ...
# 41948  0x1178   RANCHIRES16DEL01                   35                     4.2
# 41949  0x7c09      JAPRES04DEL01                   30                     4.8
# 41950  0x4f8d     CHENRES08DEL03                   30                     4.9
# 41951  0x5eee    COIMBRES11DEL01                   20                     4.7
# 41952  0x5fb2   RANCHIRES09DEL02                   23                     4.9
#
#        Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0                22.745049             75.892471                   22.765049
# 1                12.913041             77.683237                   13.043041
# 2                12.914264             77.678400                   12.924264
# 3                11.003669             76.976494                   11.053669
# 4                12.972793             80.249982                   13.012793
# ...                    ...                   ...                         ...
# 41948            23.371292             85.327872                   23.481292
# 41949            26.902328             75.794257                   26.912328
# 41950            13.022394             80.242439                   13.052394
# 41951            11.001753             76.986241                   11.041753
# 41952            23.351058             85.325731                   23.431058
#
#        Delivery_location_longitude  Order_Date Time_Orderd Time_Order_picked  \
# 0                        75.912471  19-03-2022    11:33:33          11:45:29
# 1                        77.813237  25-03-2022    19:45:37          19:51:49
# 2                        77.688400  19-03-2022     8:32:58           8:48:47
# 3                        77.026494  05-04-2022    18:03:58          18:12:52
# 4                        80.289982  26-03-2022    13:34:16          13:45:36
# ...                            ...         ...         ...               ...
# 41948                    85.437872  08-03-2022    21:47:47          21:59:27
# 41949                    75.804257  24-03-2022    11:36:22          11:48:07
# 41950                    80.272439  11-03-2022    23:50:56           0:08:55
# 41951                    77.026241  07-03-2022    13:40:13          13:42:00
# 41952                    85.405731  02-03-2022    17:12:55          17:19:35
#
#            Weatherconditions Road_traffic_density  Vehicle_condition  \
# 0           conditions Sunny                High                   2
# 1          conditions Stormy                 Jam                   2
# 2      conditions Sandstorms                 Low                   0
# 3           conditions Sunny              Medium                   0
# 4          conditions Cloudy                High                   1
# ...                      ...                  ...                ...
# 41948       conditions Windy                 Jam                   2
# 41949       conditions Windy                High                   1
# 41950      conditions Cloudy                 Low                   1
# 41951      conditions Cloudy                High                   0
# 41952         conditions Fog              Medium                   2
#
#       Type_of_order Type_of_vehicle multiple_deliveries Festival  \
# 0            Snack      motorcycle                    0      No
# 1            Snack         scooter                    1      No
# 2           Drinks      motorcycle                    1      No
# 3           Buffet      motorcycle                    1      No
# 4            Snack         scooter                    1      No
# ...             ...             ...                 ...      ...
# 41948       Drinks      motorcycle                    1      No
# 41949         Meal      motorcycle                    0      No
# 41950       Drinks         scooter                    0      No
# 41951        Snack      motorcycle                    1      No
# 41952        Snack         scooter                    1      No
#
#                  City Time_taken(min)
# 0              Urban         (min) 24
# 1      Metropolitian         (min) 33
# 2              Urban         (min) 26
# 3      Metropolitian         (min) 21
# 4      Metropolitian         (min) 30
# ...               ...             ...
# 41948  Metropolitian         (min) 33
# 41949  Metropolitian         (min) 32
# 41950  Metropolitian         (min) 16
# 41951  Metropolitian         (min) 26
# 41952  Metropolitian         (min) 36
#
# [41953 rows x 20 columns]

# %%
df.isnull().sum()
# Out:
# ID                                0
# Delivery_person_ID                0
# Delivery_person_Age               0
# Delivery_person_Ratings           0
# Restaurant_latitude               0
# Restaurant_longitude              0
# Delivery_location_latitude        0
# Delivery_location_longitude       0
# Order_Date                        0
# Time_Orderd                    1600
# Time_Order_picked                 0
# Weatherconditions                 0
# Road_traffic_density              0
# Vehicle_condition                 0
# Type_of_order                     0
# Type_of_vehicle                   0
# multiple_deliveries               0
# Festival                          0
# City                              0
# Time_taken(min)                   0
# dtype: int64

# %% [markdown]
# #### Since you can see the time_ordered column has many null values we cannot drop all the rows as it may affect the accuracy of the model so we should fill it strategically.
# We’re using Time_Order_picked and an estimated median preparation time to impute/fill these missing values.

# %%
# Time columns are currently stored as strings. To perform time calculations (like differences), we convert them to proper datetime objects.
# errors='coerce' means: If a value can’t be converted (e.g., blank or malformed), it becomes NaT (Not a Time = missing datetime).
df['Time_Order_picked'] = pd.to_datetime(df['Time_Order_picked'], format='%H:%M:%S', errors='coerce')
df['Time_Orderd'] = pd.to_datetime(df['Time_Orderd'], format='%H:%M:%S', errors='coerce')

# %%
# .dt.total_seconds() converts the timedelta to seconds, and we divide by 60 to get minutes.
prep_time = (df['Time_Order_picked'] - df['Time_Orderd']).dt.total_seconds() / 60
# We take the median (middle value) of all calculated prep times
median_prep_time = prep_time.median()

# %%
filtered_rows = df['Time_Orderd'].isna() & df['Time_Order_picked'].notna()
df.loc[filtered_rows, 'Time_Orderd'] = df.loc[filtered_rows, 'Time_Order_picked'] - pd.to_timedelta(median_prep_time, unit='m')

# %%
df.isnull().sum()
# Out:
# ID                             0
# Delivery_person_ID             0
# Delivery_person_Age            0
# Delivery_person_Ratings        0
# Restaurant_latitude            0
# Restaurant_longitude           0
# Delivery_location_latitude     0
# Delivery_location_longitude    0
# Order_Date                     0
# Time_Orderd                    0
# Time_Order_picked              0
# Weatherconditions              0
# Road_traffic_density           0
# Vehicle_condition              0
# Type_of_order                  0
# Type_of_vehicle                0
# multiple_deliveries            0
# Festival                       0
# City                           0
# Time_taken(min)                0
# dtype: int64

# %%
# Find every occurrence of the word conditions and replace it with nothing ('').
# regex=False ensures that the string 'conditions' is treated literally, not as a regular expression.
# Removes any leading or trailing whitespace from each value in the column.
df['Weatherconditions'] = df['Weatherconditions'].str.replace('conditions','',regex=False).str.strip()

# %%
df.describe()
# Out:
#        Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# count         41953.000000          41953.000000                41953.000000
# mean             18.911397             76.923408                   18.975064
# min               9.957144             72.768726                    9.967144
# 25%              12.986047             73.898520                   13.065996
# 50%              19.065838             76.618203                   19.123249
# 75%              22.751234             78.368855                   22.820040
# max              30.914057             88.433452                   31.054057
# std               5.467829              3.502910                    5.469616
#
#        Delivery_location_longitude                    Time_Orderd  \
# count                 41953.000000                          41953
# mean                     76.987074  1900-01-01 17:54:55.850880768
# min                      72.778726  1899-12-31 23:51:20.000000002
# 25%                      73.940327            1900-01-01 15:20:57
# 50%                      76.663622            1900-01-01 19:15:58
# 75%                      78.405467            1900-01-01 21:37:03
# max                      88.563452            1900-01-01 23:59:57
# std                       3.503073                            NaN
#
#                    Time_Order_picked  Vehicle_condition
# count                          41953       41953.000000
# mean   1900-01-01 17:39:51.540199680           1.022716
# min              1900-01-01 00:00:02           0.000000
# 25%              1900-01-01 14:37:04           0.000000
# 50%              1900-01-01 19:12:09           1.000000
# 75%              1900-01-01 21:37:15           2.000000
# max              1900-01-01 23:59:57           3.000000
# std                              NaN           0.838893

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41953 entries, 0 to 41952
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID                           41953 non-null  object
#  1   Delivery_person_ID           41953 non-null  object
#  2   Delivery_person_Age          41953 non-null  object
#  3   Delivery_person_Ratings      41953 non-null  object
#  4   Restaurant_latitude          41953 non-null  float64
#  5   Restaurant_longitude         41953 non-null  float64
#  6   Delivery_location_latitude   41953 non-null  float64
#  7   Delivery_location_longitude  41953 non-null  float64
#  8   Order_Date                   41953 non-null  object
#  9   Time_Orderd                  41953 non-null  datetime64[ns]
#  10  Time_Order_picked            41953 non-null  datetime64[ns]
#  11  Weatherconditions            41953 non-null  object
#  12  Road_traffic_density         41953 non-null  object
#  13  Vehicle_condition            41953 non-null  int64
#  14  Type_of_order                41953 non-null  object
#  15  Type_of_vehicle              41953 non-null  object
#  16  multiple_deliveries          41953 non-null  object
#  17  Festival                     41953 non-null  object
#  18  City                         41953 non-null  object
#  19  Time_taken(min)              41953 non-null  object
# dtypes: datetime64[ns](2), float64(4), int64(1), object(13)
# memory usage: 6.4+ MB

# %%
#doing the same for time taken column and converting it into numeric type
df['Time_taken(min)'] = df['Time_taken(min)'].str.replace('(min)', '', regex=False).str.strip()
df['Time_taken(min)'] = pd.to_numeric(df['Time_taken(min)'], errors='coerce')

# %%
#changing the data type of columns to numeric
df['Delivery_person_Age'] = pd.to_numeric(df['Delivery_person_Age'], errors='coerce')
df['Delivery_person_Ratings'] = pd.to_numeric(df['Delivery_person_Ratings'], errors='coerce')
df['multiple_deliveries'] = pd.to_numeric(df['multiple_deliveries'], errors='coerce')

# %%
#droping duplicates if any
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#             ID Delivery_person_ID  Delivery_person_Age  \
# 0      0x4607     INDORES13DEL02                  37.0
# 1      0xb379     BANGRES18DEL02                  34.0
# 2      0x5d6d     BANGRES19DEL01                  23.0
# 3      0x7a6a    COIMBRES13DEL02                  38.0
# 4      0x70a2     CHENRES12DEL01                  32.0
# ...        ...                ...                  ...
# 41948  0x1178   RANCHIRES16DEL01                  35.0
# 41949  0x7c09      JAPRES04DEL01                  30.0
# 41950  0x4f8d     CHENRES08DEL03                  30.0
# 41951  0x5eee    COIMBRES11DEL01                  20.0
# 41952  0x5fb2   RANCHIRES09DEL02                  23.0
#
#        Delivery_person_Ratings  Restaurant_latitude  Restaurant_longitude  \
# 0                          4.9            22.745049             75.892471
# 1                          4.5            12.913041             77.683237
# 2                          4.4            12.914264             77.678400
# 3                          4.7            11.003669             76.976494
# 4                          4.6            12.972793             80.249982
# ...                        ...                  ...                   ...
# 41948                      4.2            23.371292             85.327872
# 41949                      4.8            26.902328             75.794257
# 41950                      4.9            13.022394             80.242439
# 41951                      4.7            11.001753             76.986241
# 41952                      4.9            23.351058             85.325731
#
#        Delivery_location_latitude  Delivery_location_longitude  Order_Date  \
# 0                       22.765049                    75.912471  19-03-2022
# 1                       13.043041                    77.813237  25-03-2022
# 2                       12.924264                    77.688400  19-03-2022
# 3                       11.053669                    77.026494  05-04-2022
# 4                       13.012793                    80.289982  26-03-2022
# ...                           ...                          ...         ...
# 41948                   23.481292                    85.437872  08-03-2022
# 41949                   26.912328                    75.804257  24-03-2022
# 41950                   13.052394                    80.272439  11-03-2022
# 41951                   11.041753                    77.026241  07-03-2022
# 41952                   23.431058                    85.405731  02-03-2022
#
#               Time_Orderd   Time_Order_picked Weatherconditions  \
# 0     1900-01-01 11:33:33 1900-01-01 11:45:29             Sunny
# 1     1900-01-01 19:45:37 1900-01-01 19:51:49            Stormy
# 2     1900-01-01 08:32:58 1900-01-01 08:48:47        Sandstorms
# 3     1900-01-01 18:03:58 1900-01-01 18:12:52             Sunny
# 4     1900-01-01 13:34:16 1900-01-01 13:45:36            Cloudy
# ...                   ...                 ...               ...
# 41948 1900-01-01 21:47:47 1900-01-01 21:59:27             Windy
# 41949 1900-01-01 11:36:22 1900-01-01 11:48:07             Windy
# 41950 1900-01-01 23:50:56 1900-01-01 00:08:55            Cloudy
# 41951 1900-01-01 13:40:13 1900-01-01 13:42:00            Cloudy
# 41952 1900-01-01 17:12:55 1900-01-01 17:19:35               Fog
#
#       Road_traffic_density  Vehicle_condition Type_of_order Type_of_vehicle  \
# 0                    High                   2        Snack      motorcycle
# 1                     Jam                   2        Snack         scooter
# 2                     Low                   0       Drinks      motorcycle
# 3                  Medium                   0       Buffet      motorcycle
# 4                    High                   1        Snack         scooter
# ...                    ...                ...           ...             ...
# 41948                 Jam                   2       Drinks      motorcycle
# 41949                High                   1         Meal      motorcycle
# 41950                 Low                   1       Drinks         scooter
# 41951                High                   0        Snack      motorcycle
# 41952              Medium                   2        Snack         scooter
#
#        multiple_deliveries Festival            City  Time_taken(min)
# 0                      0.0      No           Urban                24
# 1                      1.0      No   Metropolitian                33
# 2                      1.0      No           Urban                26
# 3                      1.0      No   Metropolitian                21
# 4                      1.0      No   Metropolitian                30
# ...                    ...      ...             ...              ...
# 41948                  1.0      No   Metropolitian                33
# 41949                  0.0      No   Metropolitian                32
# 41950                  0.0      No   Metropolitian                16
# 41951                  1.0      No   Metropolitian                26
# 41952                  1.0      No   Metropolitian                36
#
# [41953 rows x 20 columns]

# %%
# Strip and lower-case categories
df['City'] = df['City'].str.strip().str.lower()
df['Road_traffic_density'] = df['Road_traffic_density'].str.strip().str.lower()
df['Weatherconditions'] = df['Weatherconditions'].str.strip().str.lower()
df['Type_of_order'] = df['Type_of_order'].str.strip().str.lower()
df['Festival'] = df['Festival'].str.strip().str.lower()

# %%
df[['Delivery_person_Age', 'Time_taken(min)']].describe()
# Out:
#        Delivery_person_Age  Time_taken(min)
# count         40234.000000     41953.000000
# mean             29.563330        26.311539
# std               5.812361         9.380753
# min              15.000000        10.000000
# 25%              25.000000        19.000000
# 50%              30.000000        26.000000
# 75%              35.000000        32.000000
# max              50.000000        54.000000

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# Delivery_person_Ratings        1763
# Delivery_person_Age            1719
# multiple_deliveries             905
# Delivery_person_ID                0
# ID                                0
# Restaurant_latitude               0
# Delivery_location_latitude        0
# Restaurant_longitude              0
# Order_Date                        0
# Time_Orderd                       0
# Time_Order_picked                 0
# Delivery_location_longitude       0
# Weatherconditions                 0
# Road_traffic_density              0
# Type_of_order                     0
# Vehicle_condition                 0
# Type_of_vehicle                   0
# Festival                          0
# City                              0
# Time_taken(min)                   0
# dtype: int64

# %%
df['City'].value_counts(), df['Road_traffic_density'].value_counts(), df['Weatherconditions'].value_counts(), df['Type_of_order'].value_counts(), df['Festival'].value_counts()
# Out:
# (City
#  metropolitian    31411
#  urban             9279
#  nan               1114
#  semi-urban         149
#  Name: count, dtype: int64,
#  Road_traffic_density
#  low       14200
#  jam       13043
#  medium    10084
#  high       4071
#  nan         555
#  Name: count, dtype: int64,
#  Weatherconditions
#  fog           7012
#  stormy        6974
#  cloudy        6932
#  sandstorms    6906
#  windy         6832
#  sunny         6728
#  nan            569
#  Name: count, dtype: int64,
#  Type_of_order
#  snack     10616
#  meal      10524
#  drinks    10445
#  buffet    10368
#  Name: count, dtype: int64,
#  Festival
#  no     40916
#  yes      822
#  nan      215
#  Name: count, dtype: int64)

# %%
df['Type_of_vehicle'].value_counts()
# Out:
# Type_of_vehicle
# motorcycle           24396
# scooter              14029
# electric_scooter      3468
# bicycle                 60
# Name: count, dtype: int64

# %% [markdown]
# ### Came across many fake null values so decided to convert it so that i can deal with them

# %%
import numpy as np
df.replace(['NaN', 'nan', 'null', 'Null', 'N/A', '', ' ', 'na', 'NA'], np.nan, inplace=True)

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# Delivery_person_Ratings        1763
# Delivery_person_Age            1719
# City                           1114
# multiple_deliveries             905
# Weatherconditions               569
# Road_traffic_density            555
# Festival                        215
# Delivery_person_ID                0
# ID                                0
# Restaurant_latitude               0
# Delivery_location_latitude        0
# Restaurant_longitude              0
# Time_Order_picked                 0
# Time_Orderd                       0
# Order_Date                        0
# Delivery_location_longitude       0
# Type_of_vehicle                   0
# Type_of_order                     0
# Vehicle_condition                 0
# Time_taken(min)                   0
# dtype: int64

# %% [markdown]
# Filling delivery person ratings by median citywise

# %%
# df['Delivery_person_Ratings'] = df.groupby('City')['Delivery_person_Ratings'].transform(
#     lambda x: x.fillna(x.median())
# )
city_median = df.groupby('City')['Delivery_person_Ratings'].transform('median')
df['Delivery_person_Ratings'] = df['Delivery_person_Ratings'].fillna(city_median)
df['Delivery_person_Ratings'] = df['Delivery_person_Ratings'].fillna(df['Delivery_person_Ratings'].median())

# %%
df['Delivery_person_Ratings'].isna().sum()
# Out:
# np.int64(0)

# %%
#ensuring there are no outliers
df = df[(df['Delivery_person_Ratings'] >= 1.0) & (df['Delivery_person_Ratings'] <= 5.0)]

# %%
df['Delivery_person_Ratings'].value_counts().sort_index()
# Out:
# Delivery_person_Ratings
# 1.0      35
# 2.5      18
# 2.6      20
# 2.7      21
# 2.8      17
# 2.9      18
# 3.0       6
# 3.1      28
# 3.2      26
# 3.3      23
# 3.4      32
# 3.5     236
# 3.6     194
# 3.7     203
# 3.8     218
# 3.9     176
# 4.0     998
# 4.1    1323
# 4.2    1331
# 4.3    1301
# 4.4    1246
# 4.5    3067
# 4.6    6398
# 4.7    8280
# 4.8    6558
# 4.9    6468
# 5.0    3666
# Name: count, dtype: int64

# %% [markdown]
# Filling city column with the most frequent city

# %%
# Fill missing values in 'City' with the most frequent city (mode)
city_mode = df['City'].mode()[0]
df['City'] = df['City'].fillna(city_mode)
df['City'].isna().sum()
# Out:
# C:\Users\omimi\AppData\Local\Temp\ipykernel_18288\2351960570.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['City'] = df['City'].fillna(city_mode)
# np.int64(0)

# %% [markdown]
# Filling delivery_person_age by the median value of the column grouped by city

# %%
city_median = df.groupby('City')['Delivery_person_Age'].transform('median')

# %%
df.loc[:, 'Delivery_person_Age'] = df['Delivery_person_Age'].fillna(city_median)
df.loc[:, 'Delivery_person_Age'] = df['Delivery_person_Age'].fillna(df['Delivery_person_Age'].median())

# %%
df = df[df['Delivery_person_Age'] >= 21]

# %% [markdown]
# Filling multiple deliveries by most frequent value i.e mode

# %%
df['multiple_deliveries'].value_counts()
# Out:
# multiple_deliveries
# 1.0    24718
# 0.0    12219
# 2.0     1793
# 3.0      319
# Name: count, dtype: int64

# %%
df.loc[:,'multiple_deliveries'] = df['multiple_deliveries'].fillna(df['multiple_deliveries'].mode()[0]).astype(int)
df['multiple_deliveries'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Filling Weather conditions by the mode value grouped by city type

# %%
df['Weatherconditions'].value_counts()
# Out:
# Weatherconditions
# fog           6649
# stormy        6642
# sandstorms    6616
# cloudy        6611
# windy         6514
# sunny         6388
# Name: count, dtype: int64

# %%
df.loc[:, 'Weatherconditions'] = df.groupby('City')['Weatherconditions'].transform(
    lambda x: x.fillna(x.mode()[0] if not x.mode().empty else 'unknown')
)

# %% [markdown]
# Filling Traffic density by the city wise mode value and festival by no

# %%
df.loc[:,'Road_traffic_density'] = df.groupby('City')['Road_traffic_density'].transform( 
    lambda x: x.fillna(x.mode()[0] if not x.mode().empty else 'unknown')
)
df['Festival'].value_counts(dropna=False)
df.loc[:,'Festival'] = df['Festival'].fillna('no')

# %%
#Checking for any remaining missing values
df.isna().sum().sort_values(ascending=False)
# Out:
# ID                             0
# Delivery_person_ID             0
# Delivery_person_Age            0
# Delivery_person_Ratings        0
# Restaurant_latitude            0
# Restaurant_longitude           0
# Delivery_location_latitude     0
# Delivery_location_longitude    0
# Order_Date                     0
# Time_Orderd                    0
# Time_Order_picked              0
# Weatherconditions              0
# Road_traffic_density           0
# Vehicle_condition              0
# Type_of_order                  0
# Type_of_vehicle                0
# multiple_deliveries            0
# Festival                       0
# City                           0
# Time_taken(min)                0
# dtype: int64

# %%
df
# Out:
#             ID Delivery_person_ID  Delivery_person_Age  \
# 0      0x4607     INDORES13DEL02                  37.0
# 1      0xb379     BANGRES18DEL02                  34.0
# 2      0x5d6d     BANGRES19DEL01                  23.0
# 3      0x7a6a    COIMBRES13DEL02                  38.0
# 4      0x70a2     CHENRES12DEL01                  32.0
# ...        ...                ...                  ...
# 41947  0x4e21     BANGRES16DEL03                  28.0
# 41948  0x1178   RANCHIRES16DEL01                  35.0
# 41949  0x7c09      JAPRES04DEL01                  30.0
# 41950  0x4f8d     CHENRES08DEL03                  30.0
# 41952  0x5fb2   RANCHIRES09DEL02                  23.0
#
#        Delivery_person_Ratings  Restaurant_latitude  Restaurant_longitude  \
# 0                          4.9            22.745049             75.892471
# 1                          4.5            12.913041             77.683237
# 2                          4.4            12.914264             77.678400
# 3                          4.7            11.003669             76.976494
# 4                          4.6            12.972793             80.249982
# ...                        ...                  ...                   ...
# 41947                      4.9            13.029198             77.570997
# 41948                      4.2            23.371292             85.327872
# 41949                      4.8            26.902328             75.794257
# 41950                      4.9            13.022394             80.242439
# 41952                      4.9            23.351058             85.325731
#
#        Delivery_location_latitude  Delivery_location_longitude  Order_Date  \
# 0                       22.765049                    75.912471  19-03-2022
# 1                       13.043041                    77.813237  25-03-2022
# 2                       12.924264                    77.688400  19-03-2022
# 3                       11.053669                    77.026494  05-04-2022
# 4                       13.012793                    80.289982  26-03-2022
# ...                           ...                          ...         ...
# 41947                   13.059198                    77.600997  30-03-2022
# 41948                   23.481292                    85.437872  08-03-2022
# 41949                   26.912328                    75.804257  24-03-2022
# 41950                   13.052394                    80.272439  11-03-2022
# 41952                   23.431058                    85.405731  02-03-2022
#
#               Time_Orderd   Time_Order_picked Weatherconditions  \
# 0     1900-01-01 11:33:33 1900-01-01 11:45:29             sunny
# 1     1900-01-01 19:45:37 1900-01-01 19:51:49            stormy
# 2     1900-01-01 08:32:58 1900-01-01 08:48:47        sandstorms
# 3     1900-01-01 18:03:58 1900-01-01 18:12:52             sunny
# 4     1900-01-01 13:34:16 1900-01-01 13:45:36            cloudy
# ...                   ...                 ...               ...
# 41947 1900-01-01 21:57:44 1900-01-01 22:03:10        sandstorms
# 41948 1900-01-01 21:47:47 1900-01-01 21:59:27             windy
# 41949 1900-01-01 11:36:22 1900-01-01 11:48:07             windy
# 41950 1900-01-01 23:50:56 1900-01-01 00:08:55            cloudy
# 41952 1900-01-01 17:12:55 1900-01-01 17:19:35               fog
#
#       Road_traffic_density  Vehicle_condition Type_of_order Type_of_vehicle  \
# 0                     high                  2         snack     motorcycle
# 1                      jam                  2         snack        scooter
# 2                      low                  0        drinks     motorcycle
# 3                   medium                  0        buffet     motorcycle
# 4                     high                  1         snack        scooter
# ...                    ...                ...           ...             ...
# 41947                  jam                  1          meal        scooter
# 41948                  jam                  2        drinks     motorcycle
# 41949                 high                  1          meal     motorcycle
# 41950                  low                  1        drinks        scooter
# 41952               medium                  2         snack        scooter
#
#        multiple_deliveries Festival           City  Time_taken(min)
# 0                      0.0       no          urban               24
# 1                      1.0       no  metropolitian               33
# 2                      1.0       no          urban               26
# 3                      1.0       no  metropolitian               21
# 4                      1.0       no  metropolitian               30
# ...                    ...      ...            ...              ...
# 41947                  1.0       no  metropolitian               29
# 41948                  1.0       no  metropolitian               33
# 41949                  0.0       no  metropolitian               32
# 41950                  0.0       no  metropolitian               16
# 41952                  1.0       no  metropolitian               36
#
# [39908 rows x 20 columns]

# %%
# Convert Delivery_person_Age and multiple_deliveries to int
df[ 'Delivery_person_Age'] = df['Delivery_person_Age'].astype(int)
df['multiple_deliveries'] = df['multiple_deliveries'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 39908 entries, 0 to 41952
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID                           39908 non-null  object
#  1   Delivery_person_ID           39908 non-null  object
#  2   Delivery_person_Age          39908 non-null  int64
#  3   Delivery_person_Ratings      39908 non-null  float64
#  4   Restaurant_latitude          39908 non-null  float64
#  5   Restaurant_longitude         39908 non-null  float64
#  6   Delivery_location_latitude   39908 non-null  float64
#  7   Delivery_location_longitude  39908 non-null  float64
#  8   Order_Date                   39908 non-null  object
#  9   Time_Orderd                  39908 non-null  datetime64[ns]
#  10  Time_Order_picked            39908 non-null  datetime64[ns]
#  11  Weatherconditions            39908 non-null  object
#  12  Road_traffic_density         39908 non-null  object
#  13  Vehicle_condition            39908 non-null  int64
#  14  Type_of_order                39908 non-null  object
#  15  Type_of_vehicle              39908 non-null  object
#  16  multiple_deliveries          39908 non-null  int64
#  17  Festival                     39908 non-null  object
#  18  City                         39908 non-null  object
#  19  Time_taken(min)              39908 non-null  int64
# dtypes: datetime64[ns](2), float64(5), int64(4), object(9)
# memory usage: 6.4+ MB

# %%
df
# Out:
#             ID Delivery_person_ID  Delivery_person_Age  \
# 0      0x4607     INDORES13DEL02                    37
# 1      0xb379     BANGRES18DEL02                    34
# 2      0x5d6d     BANGRES19DEL01                    23
# 3      0x7a6a    COIMBRES13DEL02                    38
# 4      0x70a2     CHENRES12DEL01                    32
# ...        ...                ...                  ...
# 41947  0x4e21     BANGRES16DEL03                    28
# 41948  0x1178   RANCHIRES16DEL01                    35
# 41949  0x7c09      JAPRES04DEL01                    30
# 41950  0x4f8d     CHENRES08DEL03                    30
# 41952  0x5fb2   RANCHIRES09DEL02                    23
#
#        Delivery_person_Ratings  Restaurant_latitude  Restaurant_longitude  \
# 0                          4.9            22.745049             75.892471
# 1                          4.5            12.913041             77.683237
# 2                          4.4            12.914264             77.678400
# 3                          4.7            11.003669             76.976494
# 4                          4.6            12.972793             80.249982
# ...                        ...                  ...                   ...
# 41947                      4.9            13.029198             77.570997
# 41948                      4.2            23.371292             85.327872
# 41949                      4.8            26.902328             75.794257
# 41950                      4.9            13.022394             80.242439
# 41952                      4.9            23.351058             85.325731
#
#        Delivery_location_latitude  Delivery_location_longitude  Order_Date  \
# 0                       22.765049                    75.912471  19-03-2022
# 1                       13.043041                    77.813237  25-03-2022
# 2                       12.924264                    77.688400  19-03-2022
# 3                       11.053669                    77.026494  05-04-2022
# 4                       13.012793                    80.289982  26-03-2022
# ...                           ...                          ...         ...
# 41947                   13.059198                    77.600997  30-03-2022
# 41948                   23.481292                    85.437872  08-03-2022
# 41949                   26.912328                    75.804257  24-03-2022
# 41950                   13.052394                    80.272439  11-03-2022
# 41952                   23.431058                    85.405731  02-03-2022
#
#               Time_Orderd   Time_Order_picked Weatherconditions  \
# 0     1900-01-01 11:33:33 1900-01-01 11:45:29             sunny
# 1     1900-01-01 19:45:37 1900-01-01 19:51:49            stormy
# 2     1900-01-01 08:32:58 1900-01-01 08:48:47        sandstorms
# 3     1900-01-01 18:03:58 1900-01-01 18:12:52             sunny
# 4     1900-01-01 13:34:16 1900-01-01 13:45:36            cloudy
# ...                   ...                 ...               ...
# 41947 1900-01-01 21:57:44 1900-01-01 22:03:10        sandstorms
# 41948 1900-01-01 21:47:47 1900-01-01 21:59:27             windy
# 41949 1900-01-01 11:36:22 1900-01-01 11:48:07             windy
# 41950 1900-01-01 23:50:56 1900-01-01 00:08:55            cloudy
# 41952 1900-01-01 17:12:55 1900-01-01 17:19:35               fog
#
#       Road_traffic_density  Vehicle_condition Type_of_order Type_of_vehicle  \
# 0                     high                  2         snack     motorcycle
# 1                      jam                  2         snack        scooter
# 2                      low                  0        drinks     motorcycle
# 3                   medium                  0        buffet     motorcycle
# 4                     high                  1         snack        scooter
# ...                    ...                ...           ...             ...
# 41947                  jam                  1          meal        scooter
# 41948                  jam                  2        drinks     motorcycle
# 41949                 high                  1          meal     motorcycle
# 41950                  low                  1        drinks        scooter
# 41952               medium                  2         snack        scooter
#
#        multiple_deliveries Festival           City  Time_taken(min)
# 0                        0       no          urban               24
# 1                        1       no  metropolitian               33
# 2                        1       no          urban               26
# 3                        1       no  metropolitian               21
# 4                        1       no  metropolitian               30
# ...                    ...      ...            ...              ...
# 41947                    1       no  metropolitian               29
# 41948                    1       no  metropolitian               33
# 41949                    0       no  metropolitian               32
# 41950                    0       no  metropolitian               16
# 41952                    1       no  metropolitian               36
#
# [39908 rows x 20 columns]

# %%
df.describe()
# Out:
#        Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude  \
# count         39908.000000             39908.000000         39908.000000
# mean             30.024757                 4.634502            18.916897
# min              21.000000                 2.500000             9.957144
# 25%              26.000000                 4.500000            12.986047
# 50%              30.000000                 4.700000            19.065838
# 75%              35.000000                 4.800000            22.751234
# max              39.000000                 5.000000            30.914057
# std               5.357983                 0.308651             5.466447
#
#        Restaurant_longitude  Delivery_location_latitude  \
# count          39908.000000                39908.000000
# mean              76.921955                   18.980579
# min               72.768726                    9.967144
# 25%               73.897902                   13.066279
# 50%               76.618203                   19.124049
# 75%               78.368855                   22.820048
# max               88.433452                   31.054057
# std                3.503813                    5.468178
#
#        Delivery_location_longitude                    Time_Orderd  \
# count                 39908.000000                          39908
# mean                     76.985637  1900-01-01 17:55:14.630650368
# min                      72.778726  1899-12-31 23:51:20.000000002
# 25%                      73.940327     1900-01-01 15:21:15.500000
# 50%                      76.662278            1900-01-01 19:16:32
# 75%                      78.405467     1900-01-01 21:37:21.500000
# max                      88.563452            1900-01-01 23:59:57
# std                       3.504007                            NaN
#
#                    Time_Order_picked  Vehicle_condition  multiple_deliveries  \
# count                          39908       39908.000000         39908.000000
# mean   1900-01-01 17:39:55.180114176           1.019044             0.754736
# min              1900-01-01 00:00:02           0.000000             0.000000
# 25%    1900-01-01 14:37:21.750000128           0.000000             0.000000
# 50%       1900-01-01 19:12:40.500000           1.000000             1.000000
# 75%    1900-01-01 21:37:37.249999872           2.000000             1.000000
# max              1900-01-01 23:59:57           3.000000             3.000000
# std                              NaN           0.836370             0.568273
#
#        Time_taken(min)
# count     39908.000000
# mean         26.482284
# min          10.000000
# 25%          19.000000
# 50%          26.000000
# 75%          33.000000
# max          54.000000
# std           9.386411

# %%
df['Order_Date'] = pd.to_datetime(df['Order_Date'], format='%d-%m-%Y', errors='coerce')

# %%
df['Time_Orderd'] = pd.to_datetime(df['Time_Orderd'], errors='coerce').dt.time
df['Time_Order_picked'] = pd.to_datetime(df['Time_Order_picked'], errors='coerce').dt.time

# %%
df.to_csv("cleaned_dataset.csv", index=False)
